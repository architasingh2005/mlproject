# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# Running cells with 'venv (Python 3.8.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n venv ipykernel --update-deps --force-reinstall'
# The kernel failed to start as the Python Environment 'Python 3.8.0' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
# The kernel failed to start as the Python Environment 'venv (3.8.0) (Python 3.8.0)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
# The kernel failed to start as the Python Environment 'venv (3.8.0) (Python 3.8.0)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
# The kernel failed to start as the Python Environment 'venv (3.8.0) (Python 3.8.0)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
# ...
